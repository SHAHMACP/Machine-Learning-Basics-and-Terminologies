# %% [markdown]
# Import libraries

# %%
import pandas as pd

# %% [markdown]
# Load the dataset

# %%
data = pd.read_csv("/content/dataset.csv")
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# Remove the unwanted columns

# %%
data = data.drop(['Loan_ID'],axis=1)
data
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %% [markdown]
# keeping a copy

# %%
datasetOriginal = data.copy()

# %% [markdown]
# # **Describe the data**

# %%
print("Data Description")
data.describe()
# Out:
# Data Description
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
print("Top 5")
data.head(5)
# Out:
# Top 5
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         NaN             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# ...

# %%
print("Columns")
data.columns
# Out:
# Columns
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
print("Shape")
data.shape
# Out:
# Shape
# (614, 12)

# %%
print("Info")
data.info()
# Out:
# Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             601 non-null    object
#  1   Married            611 non-null    object
#  2   Dependents         599 non-null    object
#  3   Education          614 non-null    object
#  4   Self_Employed      582 non-null    object
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         592 non-null    float64
#  8   Loan_Amount_Term   600 non-null    float64
#  9   Credit_History     564 non-null    float64
#  10  Property_Area      614 non-null    object
#  11  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 57.7+ KB

# %% [markdown]
# # check null values

# %%
print("Null values in each feature")
data.isnull().sum()
# Out:
# Null values in each feature
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
print("\nDatatypes")
data.dtypes
# Out:
# Datatypes
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %% [markdown]
# # **Missing value Handling**

# %% [markdown]
# Take copy

# %%
datacopy = data.copy()

# %% [markdown]
# Remove missing values

# %%
print("Before missing value removal, number of rows with missing values are \n",datacopy.isnull().sum())
print("Shape of dataset before missing value removal",datacopy.shape)
datacopy = datacopy.dropna()
print("\nAfter missing value removal, number of rows with missing values are \n",datacopy.isnull().sum())
print("Shape of dataset after missing value removal",datacopy.shape)
# Out:
# Before missing value removal, number of rows with missing values are
#  Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64
# Shape of dataset before missing value removal (614, 12)
#
# After missing value removal, number of rows with missing values are
#  Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64
# Shape of dataset after missing value removal (480, 12)

# %% [markdown]
# Missing value imputation with SimpleImputer

# %%
datacopy = data.copy()

# %%
print("Before SimpleImputer, number of rows with missing values are \n",datacopy.isnull().sum())
print("Shape of dataset before SimpleImputer",datacopy.shape)

from sklearn.impute import SimpleImputer

categorical_imputer = SimpleImputer(strategy='most_frequent')
numerical_imputer = SimpleImputer(strategy='mean')

for column in datacopy.columns:
    if datacopy[column].dtype in ['int64', 'float64']:
        datacopy[column] = numerical_imputer.fit_transform(datacopy[[column]]).ravel()
    else:
        datacopy[column] = categorical_imputer.fit_transform(datacopy[[column]]).ravel()

print("After SimpleImputer, number of rows with missing values are \n",datacopy.isnull().sum())
print("Shape of dataset after SimpleImputer",datacopy.shape)
# Out:
# Before SimpleImputer, number of rows with missing values are
#  Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64
# Shape of dataset before SimpleImputer (614, 12)
# After SimpleImputer, number of rows with missing values are
#  Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64
# Shape of dataset after SimpleImputer (614, 12)

# %% [markdown]
# Missing value imputation with KNNimputer -  Only work with numerical values. So dont run

# %%
from sklearn.impute import KNNImputer
print("Before KNNimputer, number of rows with missing values are \n",datacopy.isnull().sum())
print("Shape of dataset before KNNimputer",datacopy.shape)

imputer = KNNImputer(n_neighbors=5)
datacopy = pd.DataFrame(imputer.fit_transform(datacopy), columns=datacopy.columns)

print("After KNNImputer, number of rows with missing values are \n",datacopy.isnull().sum())
print("Shape of dataset after KNNImputer",datacopy.shape)
# Out:
# Before KNNimputer, number of rows with missing values are
#  Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64
# Shape of dataset before KNNimputer (614, 12)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-a57b33d3f09d> in <cell line: 0>()
#       4
#       5 imputer = KNNImputer(n_neighbors=5)
# ----> 6 datacopy = pd.DataFrame(imputer.fit_transform(datacopy), columns=datacopy.columns)
#       7
#       8 print("After KNNImputer, number of rows with missing values are \n",datacopy.isnull().sum())
#
# ...

# %%
data = datacopy.copy()

# %% [markdown]
# # **Distribution Analysis**

# %% [markdown]
# Show Target Distributions

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, ax = plt.subplots(2, 3,figsize=(30, 30))
sns.countplot(x="Gender", hue="Loan_Status", data=data, ax=ax[0, 0])
sns.countplot(x="Married", hue="Loan_Status", data=data, ax=ax[0, 1])
sns.countplot(x="Dependents", hue="Loan_Status", data=data, ax=ax[0, 2])
sns.countplot(x="Education", hue="Loan_Status", data=data, ax=ax[1, 0])
sns.countplot(x="Self_Employed", hue="Loan_Status", data=data, ax=ax[1, 1])
sns.countplot(x="Credit_History", hue="Loan_Status", data=data, ax=ax[1, 2])
plt.show()

# %% [markdown]
# # **Data Encoding**

# %% [markdown]
#  Label encoding      - option 1

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
cat_columns = datacopy.select_dtypes(exclude='number').columns
for column in cat_columns:
    le.fit(datacopy[column])
    datacopy[column] = le.transform(datacopy[column])
    datacopy[column]  = datacopy[column] + 1
datacopy
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         2        1           1          1              1           5849.0
# 1         2        2           2          1              1           4583.0
# 2         2        2           1          1              2           3000.0
# 3         2        2           1          2              1           2583.0
# 4         2        1           1          1              1           6000.0
# ..      ...      ...         ...        ...            ...              ...
# 609       1        1           1          1              1           2900.0
# 610       2        2           4          1              1           4106.0
# 611       2        2           2          1              1           8072.0
# 612       2        2           3          1              1           7583.0
# 613       1        1           1          1              2           4583.0
#
# ...

# %% [markdown]
# Categorical encoding  - option 2

# %%
datacopy = data.copy()

# %%
cat_columns = datacopy.select_dtypes(exclude='number').columns
for column in cat_columns:
  datacopy[column] = datacopy[column].astype('category').cat.codes
  datacopy[column] = datacopy[column] + 1
datacopy
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         2        1           1          1              1           5849.0
# 1         2        2           2          1              1           4583.0
# 2         2        2           1          1              2           3000.0
# 3         2        2           1          2              1           2583.0
# 4         2        1           1          1              1           6000.0
# ..      ...      ...         ...        ...            ...              ...
# 609       1        1           1          1              1           2900.0
# 610       2        2           4          1              1           4106.0
# 611       2        2           2          1              1           8072.0
# 612       2        2           3          1              1           7583.0
# 613       1        1           1          1              2           4583.0
#
# ...

# %% [markdown]
# # **Outlier Handling**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
print("Before outlier removal, number of items are ", len(datacopy))

feature = 'ApplicantIncome'
ax = sns.boxplot(y=feature, data=datacopy)
plt.show()
# Out:
# Before outlier removal, number of items are  614

# %%
Q1 = datacopy[feature].quantile(0.25)
Q3 = datacopy[feature].quantile(0.75)
IQR = Q3 - Q1
lower_extream = Q1 - 1.5 * IQR
upper_extream = Q3 + 1.5 * IQR
datacopy.drop(datacopy[(datacopy[feature] > upper_extream) | (datacopy[feature] < lower_extream)].index, inplace=True)

# %%
ax = sns.boxplot(y=feature, data=datacopy)
plt.show()
print("After outlier removal, number of items are ", len(datacopy))
# Out:
# After outlier removal, number of items are  564

# %%
data = datacopy.copy()
data
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         2        1           1          1              1           5849.0
# 1         2        2           2          1              1           4583.0
# 2         2        2           1          1              2           3000.0
# 3         2        2           1          2              1           2583.0
# 4         2        1           1          1              1           6000.0
# ..      ...      ...         ...        ...            ...              ...
# 609       1        1           1          1              1           2900.0
# 610       2        2           4          1              1           4106.0
# 611       2        2           2          1              1           8072.0
# 612       2        2           3          1              1           7583.0
# 613       1        1           1          1              2           4583.0
#
# ...

# %% [markdown]
# # **Data Imbalance Handling**

# %% [markdown]
# Decide the independent and dependent features

# %%
data = datacopy.copy()

# %%
x = data[['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
       'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
       'Loan_Amount_Term', 'Credit_History', 'Property_Area']]
y = data[['Loan_Status']]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
print("Before balancing")
sns.displot(y, bins=20)
plt.show()
# Out:
# Before balancing

# %% [markdown]
# Installl the package

# %%
# !pip install imblearn

# %% [markdown]
# Under sampling           - option 1

# %%
from imblearn.under_sampling import RandomUnderSampler
sam = RandomUnderSampler(random_state=0)
X_resampled_under, y_resampled_under = sam.fit_resample(x, y)

# %%
sns.displot(y_resampled_under, bins=20)
plt.show()

# %% [markdown]
# Over sampling  - option 2

# %%
from imblearn.over_sampling import RandomOverSampler
sam= RandomOverSampler(sampling_strategy='minority')
X_resampled_over, y_resampled_over = sam.fit_resample(x, y)

# %%
sns.displot(y_resampled_over, bins=30)
plt.show()

# %% [markdown]
# Synthetic Minority Oversampling Technique - SMOTE    - Option 3

# %%
from imblearn.over_sampling import  SMOTE
smote = SMOTE(sampling_strategy='minority',k_neighbors=1)
X_resampled_smote, y_resampled_smote = smote.fit_resample(x, y)

# %%
sns.displot(y_resampled_smote, bins=30)
plt.show()

# %%
import pandas as pd
datacopy = pd.concat([X_resampled_smote,y_resampled_smote],axis=1)
print("New dataset shape after balancing\n",datacopy.shape)
# Out:
# New dataset shape after balancing
#  (778, 12)

# %% [markdown]
# TAKE DUPLICATE

# %%
data = datacopy.copy()
data
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         2        1           1          1              1      5849.000000
# 1         2        2           2          1              1      4583.000000
# 2         2        2           1          1              2      3000.000000
# 3         2        2           1          2              1      2583.000000
# 4         2        1           1          1              1      6000.000000
# ..      ...      ...         ...        ...            ...              ...
# 773       2        2           1          2              1      2589.965324
# 774       2        1           1          1              1      3014.429311
# 775       1        1           1          1              1      3418.000000
# 776       2        1           2          1              1      6462.872700
# 777       1        1           1          1              1      3418.000000
#
# ...

# %% [markdown]
# # **Feature selection**

# %%
x = datacopy[['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
                 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
                 'Loan_Amount_Term', 'Credit_History', 'Property_Area']]
y = datacopy[['Loan_Status']]
x.shape
# Out:
# (778, 11)

# %%
x.var()
# Out:
# Gender               1.821520e-01
# Married              2.435460e-01
# Dependents           8.657185e-01
# Education            1.550373e-01
# Self_Employed        7.880319e-02
# ApplicantIncome      3.716172e+06
# CoapplicantIncome    9.316929e+06
# LoanAmount           3.171095e+03
# Loan_Amount_Term     4.417369e+03
# Credit_History       1.483459e-01
# Property_Area        5.984060e-01
# dtype: float64

# %% [markdown]
# **Using VarianceThreshold   - Option 1**
#
# 📌 When to Use VarianceThreshold
# ✅ Use Case
#
#   - You want to remove features with very little variation across rows.
#
#   - Works well for both numerical and categorical (encoded) data.
#
#   - It’s an unsupervised method — doesn’t consider the target variable y.

# %%
from sklearn.feature_selection import VarianceThreshold

# Assuming x is your DataFrame
# Set a threshold — e.g., 0.01 for very low variance
selector = VarianceThreshold(threshold=0.5)
x_selected = selector.fit_transform(x)

# Get selected column names
selected_columns = x.columns[selector.get_support()]
print("Selected Features based on Variance Threshold:")
print(selected_columns)
# Out:
# Selected Features based on Variance Threshold:
# Index(['Dependents', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Property_Area'],
#       dtype='object')

# %% [markdown]
# **Univariate Selection - chi2  - Option 2**
#
#
# When to Use chi2
#
#   - Input (X): Non-negative numerical features (commonly categorical features encoded as 0/1 or ordinal integers).
#
#   - Target (y): Categorical (e.g., binary classification).
#
#   - Use Case: Find features that are statistically significant to the target.

# %%
from sklearn.feature_selection import SelectKBest,chi2
bestfeatures = SelectKBest(score_func=chi2, k=10)
fit = bestfeatures.fit(x,y)
feature_names = list(x.columns)
feature_scores = pd.DataFrame({'Feature': feature_names, 'Score':fit.scores_})
feature_scores = feature_scores.sort_values(by='Score', ascending=False)
feature_scores
# Out:
#               Feature        Score
# 6   CoapplicantIncome  2460.963933
# 5     ApplicantIncome    86.885285
# 9      Credit_History    44.015991
# 7          LoanAmount    16.818984
# 10      Property_Area     6.747638
# 1             Married     4.329001
# 2          Dependents     4.056338
# 0              Gender     1.973723
# 4       Self_Employed     0.739645
# 3           Education     0.130529
# 8    Loan_Amount_Term     0.024572

# %% [markdown]
# **Univariate Selection - mutual_info_classif - Option 3**
#
# When to use
#
#    -  You have categorical or numerical features
#    -  You want to find non-linear relationships with the target
#    -  You're working on classification problems

# %%
from sklearn.feature_selection import mutual_info_classif
scores = mutual_info_classif(x, y)
feature_names = list(x.columns)
feature_scores = pd.DataFrame({'Feature': feature_names, 'Score': scores})
feature_scores = feature_scores.sort_values(by='Score', ascending=False)
feature_scores
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#               Feature     Score
# 9      Credit_History  0.226615
# 5     ApplicantIncome  0.120099
# 8    Loan_Amount_Term  0.052268
# 6   CoapplicantIncome  0.038897
# 7          LoanAmount  0.037059
# 10      Property_Area  0.018759
# 2          Dependents  0.013690
# 1             Married  0.012278
# 4       Self_Employed  0.003239
# 0              Gender  0.000000
# 3           Education  0.000000

# %% [markdown]
# **Correlation based -  Option 4**
#   - Your data has many numerical features
#   - You want a fast, interpretable method
#   - You want to remove multicollinearity

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15,15))
corr = datacopy.corr()
sns.heatmap(corr, annot=True)
plt.show()

# %% [markdown]
# **Feature Importance based - Option 5**
# - You have a mix of categorical + numerical features
# - You want model-specific insights (e.g., tree-based models)
# - You care about non-linear relationships

# %%
from sklearn.ensemble import ExtraTreesClassifier
import pandas as pd
model = ExtraTreesClassifier()
model.fit(x,y)
feat_importances =pd.Series(model.feature_importances_,index=x.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %% [markdown]
# Forward feature selection

# %%
# !pip install mlxtend

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
model = ExtraTreesClassifier()
sfs1 = sfs(model,
               k_features=5,
               forward=True,
               floating=False,
               verbose=2,
               scoring='accuracy',
               cv=5)
sfs1 = sfs1.fit(x, y.values.ravel())
feat_names = list(sfs1.k_feature_names_)
print(feat_names)
# Out:
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:    7.4s finished
#
# [2025-06-01 07:25:39] Features: 1/5 -- score: 0.7868155500413565[Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    5.9s finished
#
# [2025-06-01 07:25:45] Features: 2/5 -- score: 0.7893961952026468[Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    7.6s finished
#
# [2025-06-01 07:25:52] Features: 3/5 -- score: 0.7983953680727874[Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    5.1s finished
#
# [2025-06-01 07:25:57] Features: 4/5 -- score: 0.8035153019023987
# ['Gender', 'Married', 'Loan_Amount_Term', 'Credit_History', 'Property_Area']
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    5.6s finished
#
# [2025-06-01 07:26:03] Features: 5/5 -- score: 0.8112324234904879

# %% [markdown]
# Backward feature selection

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
model = ExtraTreesClassifier()
sfs1 = sfs(model,
               k_features=3,
               forward=False,
               floating=False,
               verbose=2,
               scoring='accuracy',
               cv=5)
sfs1 = sfs1.fit(x, y.values.ravel())
feat_names = list(sfs1.k_feature_names_)
print(feat_names)
# Out:
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:   12.8s finished
#
# [2025-06-01 07:26:33] Features: 10/3 -- score: 0.822812241521919[Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    8.6s finished
#
# [2025-06-01 07:26:41] Features: 9/3 -- score: 0.8433664185277088[Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    8.1s finished
#
# [2025-06-01 07:26:49] Features: 8/3 -- score: 0.8446401985111663[Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    7.9s finished
#
# [2025-06-01 07:26:57] Features: 7/3 -- score: 0.8549214226633582[Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    8.1s finished
#
# [2025-06-01 07:27:05] Features: 6/3 -- score: 0.8588172043010752[Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    4.4s finished
#
# [2025-06-01 07:27:10] Features: 5/3 -- score: 0.8459636062861868[Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    3.7s finished
#
# [2025-06-01 07:27:13] Features: 4/3 -- score: 0.8240694789081886
# ...

# %% [markdown]
# # **Feature Transformation / Feature scaling**

# %% [markdown]
# **skewness-reducing transformations or power transformations.**

# %%
datacopy = data.copy()

# %%
#['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed','ApplicantIncome', 'CoapplicantIncome', 'LoanAmount','Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status']

feature="ApplicantIncome"

print("skewness of "+ str(feature)+" "+str(datacopy[feature].skew())+"\n\n")
sns.distplot(datacopy[feature], bins=30)
plt.show()
# Out:
# skewness of ApplicantIncome 1.1199566352734598
# <ipython-input-135-575080993b24>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(datacopy[feature], bins=30)

# %% [markdown]
# Feature distribution ploting and skewness checking
#
# *  -0.5 < Symmetrical < +0.5
# *  -1.0 < Moderate Negatively skewed < -0.5
# *  0.5 < Moderate Positively skewed < +1.0
# *  Negatively skewed < -1.0
# *  Positively skewed > +1.0

# %%
import numpy as np
import scipy.stats as stats

mode = "exp"

if(mode=="log"):
    datacopy[feature] = np.log(datacopy[feature])
elif(mode=="reci"):
    datacopy[feature] = 1/datacopy[feature]
elif (mode == "sqrt"):
    datacopy[feature] = np.sqrt(datacopy[feature])
elif (mode == "exp"):
    datacopy[feature] = datacopy[feature]**(1/1.2)
elif (mode == "box"):
    datacopy[feature], parameters = stats.boxcox(datacopy[feature])

#datacopy[feature] = np.log(datacopy[feature])

# %%
print("skewness of "+ str(feature)+" "+str(datacopy[feature].skew())+"\n\n")
sns.distplot(datacopy[feature], bins=30)
plt.show()
# Out:
# skewness of ApplicantIncome 0.9322786994479151
# <ipython-input-138-eea022b64bc2>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(datacopy[feature], bins=30)

# %% [markdown]
# **Nomalization(0-1 Range)**

# %%
datacopy = data.copy()

# %%
from sklearn.preprocessing import MinMaxScaler
from pandas import DataFrame

#Normalizing only features
features = datacopy[['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
       'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
       'Loan_Amount_Term', 'Credit_History', 'Property_Area']]

y = datacopy[['Loan_Status']]

featurescopy = features.copy()
scalarObject = MinMaxScaler().fit(features)
scaledFeatures = scalarObject.transform(features)
scaledFeaturesDF = DataFrame(scaledFeatures,columns=featurescopy.columns)
scaledFeaturesDF
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1.0      0.0    0.000000        0.0            0.0         0.570528
# 1       1.0      1.0    0.333333        0.0            0.0         0.443788
# 2       1.0      1.0    0.000000        0.0            1.0         0.285314
# 3       1.0      1.0    0.000000        1.0            0.0         0.243568
# 4       1.0      0.0    0.000000        0.0            0.0         0.585644
# ..      ...      ...         ...        ...            ...              ...
# 773     1.0      1.0    0.000000        1.0            0.0         0.244265
# 774     1.0      0.0    0.000000        0.0            0.0         0.286758
# 775     0.0      0.0    0.000000        0.0            0.0         0.327160
# 776     1.0      0.0    0.333333        0.0            0.0         0.631982
# 777     0.0      0.0    0.000000        0.0            0.0         0.327160
#
# ...

# %% [markdown]
# **Standardisation (Mean 0, STD=1, variance =1)**

# %%
datacopy = data.copy()

# %%
from sklearn.preprocessing import StandardScaler
from pandas import DataFrame

#Standardizing only features
features = datacopy[['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
       'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
       'Loan_Amount_Term', 'Credit_History', 'Property_Area']]

featurescopy = features.copy()
scalarObject = StandardScaler().fit(features)
scaledFeatures = scalarObject.transform(features)
scaledFeaturesDF = DataFrame(scaledFeatures,columns=featurescopy.columns)
scaledFeaturesDF
# Out:
#        Gender   Married  Dependents  Education  Self_Employed  \
# 0    0.560526 -1.180613   -0.691164  -0.486707      -0.306975
# 1    0.560526  0.847018    0.384287  -0.486707      -0.306975
# 2    0.560526  0.847018   -0.691164  -0.486707       3.257597
# 3    0.560526  0.847018   -0.691164   2.054623      -0.306975
# 4    0.560526 -1.180613   -0.691164  -0.486707      -0.306975
# ..        ...       ...         ...        ...            ...
# 773  0.560526  0.847018   -0.691164   2.054623      -0.306975
# 774  0.560526 -1.180613   -0.691164  -0.486707      -0.306975
# 775 -1.784039 -1.180613   -0.691164  -0.486707      -0.306975
# 776  0.560526 -1.180613    0.384287  -0.486707      -0.306975
# 777 -1.784039 -1.180613   -0.691164  -0.486707      -0.306975
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0           0.895575          -0.545523    0.217054          0.281745
# 1           0.238424          -0.051162   -0.110120          0.281745
# ...

# %% [markdown]
# Concatinating with Prediction Column

# %%
datacopy = pd.concat([scaledFeaturesDF,y],axis=1)
datacopy
# Out:
#        Gender   Married  Dependents  Education  Self_Employed  \
# 0    0.560526 -1.180613   -0.691164  -0.486707      -0.306975
# 1    0.560526  0.847018    0.384287  -0.486707      -0.306975
# 2    0.560526  0.847018   -0.691164  -0.486707       3.257597
# 3    0.560526  0.847018   -0.691164   2.054623      -0.306975
# 4    0.560526 -1.180613   -0.691164  -0.486707      -0.306975
# ..        ...       ...         ...        ...            ...
# 773  0.560526  0.847018   -0.691164   2.054623      -0.306975
# 774  0.560526 -1.180613   -0.691164  -0.486707      -0.306975
# 775 -1.784039 -1.180613   -0.691164  -0.486707      -0.306975
# 776  0.560526 -1.180613    0.384287  -0.486707      -0.306975
# 777 -1.784039 -1.180613   -0.691164  -0.486707      -0.306975
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0           0.895575          -0.545523    0.217054          0.281745
# 1           0.238424          -0.051162   -0.110120          0.281745
# ...

# %%
data = datacopy.copy()
data
# Out:
#        Gender   Married  Dependents  Education  Self_Employed  \
# 0    0.560526 -1.180613   -0.691164  -0.486707      -0.306975
# 1    0.560526  0.847018    0.384287  -0.486707      -0.306975
# 2    0.560526  0.847018   -0.691164  -0.486707       3.257597
# 3    0.560526  0.847018   -0.691164   2.054623      -0.306975
# 4    0.560526 -1.180613   -0.691164  -0.486707      -0.306975
# ..        ...       ...         ...        ...            ...
# 773  0.560526  0.847018   -0.691164   2.054623      -0.306975
# 774  0.560526 -1.180613   -0.691164  -0.486707      -0.306975
# 775 -1.784039 -1.180613   -0.691164  -0.486707      -0.306975
# 776  0.560526 -1.180613    0.384287  -0.486707      -0.306975
# 777 -1.784039 -1.180613   -0.691164  -0.486707      -0.306975
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0           0.895575          -0.545523    0.217054          0.281745
# 1           0.238424          -0.051162   -0.110120          0.281745
# ...

# %% [markdown]
# 1. Handle Missing Values
# 2. Fix Skewness (log, sqrt, boxcox, etc.)
# 3. Scale Data:
#    - Use Standardization **OR**
#    - Use Normalization
#   ![Screenshot 2025-06-01 140324.png](data:image/png;base64,...)

# %% [markdown]
# # **Train Test Split**

# %%
from sklearn.model_selection import train_test_split

X = data[['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
                 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
                 'Loan_Amount_Term', 'Credit_History', 'Property_Area']]
y = data[['Loan_Status']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4000)
print(X_train.shape)
print(X_test.shape)
# Out:
# (622, 11)
# (156, 11)

# %% [markdown]
# # **Model Selection**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier

from sklearn.metrics import classification_report,confusion_matrix
from sklearn import metrics

from sklearn import model_selection

models = [
        ('LogReg', LogisticRegression()),
        ('RF', RandomForestClassifier()),
        ('KNN', KNeighborsClassifier()),
        ('SVM', SVC()),
        ('MLP', MLPClassifier())
    ]

scoring = ['accuracy', 'precision', 'recall', 'f1', 'roc_auc']
dfs     = []
target_names = ['1','2']
for name, model in models:
  kfold = model_selection.KFold(n_splits=5, shuffle=True, random_state=90210)
  cv_results = model_selection.cross_validate(model, X_train, y_train.values.ravel(), cv=kfold, scoring=scoring)
  clf = model.fit(X_train, y_train.values.ravel())
  y_pred = clf.predict(X_test)
  print("\n"+name)
  print(classification_report(y_test, y_pred, target_names=target_names))
  confusionMatrix = confusion_matrix(y_test, y_pred)
  cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix=confusionMatrix, display_labels=['1','2'])
  cm_display.plot()
  plt.show()
  this_df = pd.DataFrame(cv_results)
  this_df['model'] = name
  dfs.append(this_df)

finalData = pd.concat(dfs, ignore_index=True)
print(finalData)
# Out:
# LogReg
#               precision    recall  f1-score   support
#
#            1       0.84      0.67      0.74        84
#            2       0.69      0.85      0.76        72
#
#     accuracy                           0.75       156
#    macro avg       0.76      0.76      0.75       156
# weighted avg       0.77      0.75      0.75       156
# RF
#               precision    recall  f1-score   support
#
#            1       0.85      0.76      0.81        84
#            2       0.75      0.85      0.80        72
#
#     accuracy                           0.80       156
#    macro avg       0.80      0.80      0.80       156
# weighted avg       0.81      0.80      0.80       156
# KNN
#               precision    recall  f1-score   support
#
#            1       0.80      0.73      0.76        84
#            2       0.71      0.79      0.75        72
#
#     accuracy                           0.76       156
#    macro avg       0.76      0.76      0.76       156
# ...

# %% [markdown]
# # **Hyper parameter tuning**

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
param_grid = {
    'n_estimators': [25,100],
    'max_features': ['sqrt', 'log2'],
    'criterion':['gini', 'entropy', 'log_loss'],
    'max_depth': [9,10],
    'max_leaf_nodes': [6,11]
}
grid_search = GridSearchCV(RandomForestClassifier(), param_grid, cv=cv)
grid_search.fit(X_train, y_train.values.ravel())
grid_search.best_estimator_
# Out:
# RandomForestClassifier(max_depth=10, max_leaf_nodes=11)

# %%
print(grid_search.best_params_)
# Out:
# {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 11, 'n_estimators': 100}

# %% [markdown]
# Plot tree

# %%
from sklearn.tree import plot_tree
rf_best = grid_search.best_estimator_
plt.figure(figsize=(80, 40))
plot_tree(rf_best.estimators_[3], feature_names=X_train.columns, class_names=['1', '2'],filled=True);
plt.show()

# %% [markdown]
# # **Final Model Training  - Optional**

# %%
from sklearn.ensemble import RandomForestClassifier
import pickle
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

classifier_rf = RandomForestClassifier(criterion='gini',
                                       max_depth=10,
                                       max_features='sqrt',
                                       max_leaf_nodes=11,
                                       n_estimators=100)
classifier_rf.fit(X_train, y_train)
y_pred = classifier_rf.predict(X_test)

cm = confusion_matrix(y_test, y_pred)
ax = sns.heatmap(cm, annot=True, fmt='d').set_title('Confusion Metrix')
plt.show()
print(classification_report(y_test, y_pred))
print(accuracy_score(y_test, y_pred))
pickle.dump(classifier_rf, open('model.pkl', 'wb'))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
#               precision    recall  f1-score   support
#
#            1       0.89      0.69      0.78        84
#            2       0.71      0.90      0.80        72
#
#     accuracy                           0.79       156
#    macro avg       0.80      0.80      0.79       156
# weighted avg       0.81      0.79      0.79       156
#
# 0.7884615384615384

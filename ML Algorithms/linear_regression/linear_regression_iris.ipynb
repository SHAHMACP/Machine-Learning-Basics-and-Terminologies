# %% [markdown]
# <a href="https://colab.research.google.com/github/SHAHMACP/Machine-Learning-Basics-and-Terminologies/blob/main/ML%20Algorithms/linear_regression/linear_regression_iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
iris=sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ##### Simple linear regression with single variable

# %%
iris=iris[['petal_length','petal_width']]
iris
# Out:
#      petal_length  petal_width
# 0             1.4          0.2
# 1             1.4          0.2
# 2             1.3          0.2
# 3             1.5          0.2
# 4             1.4          0.2
# ..            ...          ...
# 145           5.2          2.3
# 146           5.0          1.9
# 147           5.2          2.0
# 148           5.4          2.3
# 149           5.1          1.8
#
# [150 rows x 2 columns]

# %% [markdown]
# y=mx+c , Let, x= petal_length and y=petal_width

# %%
x=iris[['petal_length']]
y=iris[['petal_width']]

# %% [markdown]
# ##### To apply linear regression , there should be a linear relation between the dependent and independent variable.

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
# Out:
# Text(0, 0.5, 'Petal Width')

# %% [markdown]
# ##### Scatter plot shows a positive correlation between petal length and petal width

# %% [markdown]
# ##### Splitting the dataset to train and test the model

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=23)

# %%
x_train
# Out:
#      petal_length
# 77            5.0
# 29            1.6
# 92            4.0
# 23            1.7
# 128           5.6
# ..            ...
# 39            1.5
# 91            4.6
# 31            1.5
# 40            1.3
# 83            5.1
#
# [90 rows x 1 columns]

# %%
print(type(x_train))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
from sklearn.linear_model import LinearRegression

# %%
#creating object for LinearRegression class
lr=LinearRegression()

# %% [markdown]
# After calling fit(), the linear regression model will be trained using the provided training data, and it will learn the relationship between the features and the target values. The model will adjust its parameters (coefficients) to minimize the difference between the predicted values and the actual target values.

# %%
#  train the model with the provided training data
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# y=mx+c c=intercept
c=lr.intercept_
c
# Out:
# array([-0.35113274])

# %%
# y=mx+c m=slope
m=lr.coef_
m
# Out:
# array([[0.41684538]])

# %%
# predicted values using predict()
predicted_train=lr.predict(x_train)

# %% [markdown]
# After executing this line of code, predicted_train will contain the predicted values for the target variable based on the features in the training data. These predicted values can then be compared with the actual target values (y_train) to evaluate the performance of the model or for any further analysis.

# %%
predicted_train
# Out:
# array([[1.73309416],
#        [0.31581987],
#        [1.31624878],
#        [0.3575044 ],
#        [1.98320139],
#        [1.31624878],
#        [1.64972508],
#        [1.98320139],
#        [1.7747787 ],
#        [1.69140962],
#        [0.23245079],
#        [0.31581987],
#        [1.98320139],
#        [0.23245079],
#        [0.31581987],
#        [1.94151685],
#        [1.7747787 ],
#        [1.31624878],
#        [0.23245079],
#        [1.35793332],
#        [1.85814777],
#        [1.52467147],
#        [2.06657046],
#        [2.40004677],
#        [1.44130239],
#        [0.19076625],
#        [1.31624878],
#        [1.69140962],
#        [1.69140962],
#        [1.31624878],
#        [0.27413533],
#        [1.52467147],
#        [1.52467147],
#        [1.27456424],
#        [1.73309416],
#        [1.64972508],
#        [1.2328797 ],
#        [1.7747787 ],
#        [2.27499315],
#        [2.19162408],
#        [0.14908171],
#        [2.02488593],
#        [0.8994034 ],
# ...

# %%
predicted_test=lr.predict(x_test)

# %%
predicted_test
# Out:
# array([[1.89983231],
#        [2.14993954],
#        [1.35793332],
#        [0.27413533],
#        [1.73309416],
#        [1.69140962],
#        [0.3575044 ],
#        [1.94151685],
#        [0.3575044 ],
#        [1.14951063],
#        [1.60804055],
#        [0.31581987],
#        [2.108255  ],
#        [0.27413533],
#        [0.27413533],
#        [1.7747787 ],
#        [1.52467147],
#        [1.60804055],
#        [2.19162408],
#        [0.23245079],
#        [1.85814777],
#        [0.23245079],
#        [0.31581987],
#        [0.19076625],
#        [1.98320139],
#        [0.23245079],
#        [0.44087348],
#        [1.64972508],
#        [1.48298693],
#        [1.27456424],
#        [0.27413533],
#        [1.27456424],
#        [0.19076625],
#        [2.44173131],
#        [0.27413533],
#        [0.3575044 ],
#        [1.56635601],
#        [1.02445701],
#        [1.39961786],
#        [2.14993954],
#        [2.02488593],
#        [0.44087348],
#        [1.19119517],
# ...

# %%
x_train.iloc[0]
# Out:
# petal_length    5.0
# Name: 77, dtype: float64

# %%
predicted_train[0]
# Out:
# array([1.73309416])

# %%
# from x_train consider the value x=5.0 and find out the predicted value using the equation y=mx+c
m*5.0+c
# Out:
# array([[1.73309416]])

# %% [markdown]
# As expected, Got the same value for predict() and mx+c

# %%
y_train.iloc[0]
# Out:
# petal_width    1.7
# Name: 77, dtype: float64

# %% [markdown]
# ##### For x=5.0
# ##### predicted value = 1.73309416
# ##### Actual value =   1.7

# %%
x_test
# Out:
#      petal_length
# 139           5.4
# 125           6.0
# 67            4.1
# 3             1.5
# 113           5.0
# 52            4.9
# 18            1.7
# 137           5.5
# 20            1.7
# 64            3.6
# 73            4.7
# 30            1.6
# 102           5.9
# 19            1.5
# 10            1.5
# 133           5.1
# 51            4.5
# 63            4.7
# 135           6.1
# 28            1.4
# 115           5.3
# 45            1.4
# 46            1.6
# 2             1.3
# 140           5.6
# 17            1.4
# 44            1.9
# 126           4.8
# 75            4.4
# 69            3.9
# 9             1.5
# 59            3.9
# 16            1.3
# 122           6.7
# 7             1.5
# 5             1.7
# 54            4.6
# 93            3.3
# 95            4.2
# 100           6.0
# 120           5.7
# 24            1.9
# 81            3.7
# 47            1.4
# 87            4.4
# 146           5.0
# 106           4.5
# 131           6.4
# 34            1.5
# ...

# %%
x_test.iloc[1]
# Out:
# petal_length    6.0
# Name: 125, dtype: float64

# %%
predicted_test[1]
# Out:
# array([2.14993954])

# %%
y_test.iloc[1]
# Out:
# petal_width    1.8
# Name: 125, dtype: float64

# %%
#error=predicted - actual
2.14993954 -  1.8
# Out:
# 0.34993954000000005

# %%
import matplotlib.pyplot as plt
plt.scatter(x_train,y_train)
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
# Out:
# Text(0, 0.5, 'Petal Width')

# %%
import matplotlib.pyplot as plt

# Scatter plot of training data
plt.scatter(x_train,y_train)

# Plot the predictions made by the model
plt.plot(x_train,predicted_train,color='red')

plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.show()

# %%
# Best fit line to the test data
import matplotlib.pyplot as plt
plt.scatter(x_test,y_test)
plt.plot(x_test,predicted_test,color='red')
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.show()

# %% [markdown]
# ### Evaluation

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_test,predicted_test)
mse
# Out:
# 0.04715090722659736

# %% [markdown]
# ##### Lower values of MSE indicate better model performance, as they imply that the model's predictions are closer to the actual values on average.
# ##### MSE value of 0.0391 suggests relatively low error

# %%
rmse=np.sqrt(mse)
rmse
# Out:
# 0.1977703591841455

# %% [markdown]
# ##### A Root Mean Squared Error (RMSE) value of 0.1977 means that, on average, the difference between the actual petal widths and the predicted petal widths is approximately 0.1977 units.

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, predicted_test)
r2
# Out:
# 0.9207765993420344

# %% [markdown]
# ##### Higher R-squared values indicate better fit of the model to the data. A score of 0.9307 suggests that the linear regression model fits the data very well

# %% [markdown]
# R-squared values range from 0 to 1

# %%
# lr.score(x_train, y_train) calculates the R-squared score on the training data
# This represents how well the model fits the training data.
lr.score(x_train,y_train)
# Out:
# 0.9307444954156013

# %%
# lr.score(x_test, y_test) calculates the R-squared score on the test data .
# This represents how well the model generalizes to unseen data.
lr.score(x_test,y_test)
# Out:
# 0.9207765993420344

# %% [markdown]
# ##### The score() method returns the R-squared value by default for regression models like linear regression. This value ranges between 0 and 1, where a higher value indicates a better fit of the model to the data.

# %% [markdown]
# ##### By comparing the R-squared scores on both training and test data, you can assess the model's performance and whether it is overfitting or underfitting. If the R-squared score is significantly higher on the training data compared to the test data, it may indicate overfitting. Conversely, if the scores are similar but low, it may indicate underfitting.

# %%
#cross validation
from sklearn.model_selection import cross_val_score
scores=cross_val_score(lr,x_train,y_train,cv=5)

# %%
scores
# Out:
# array([0.91884619, 0.92453551, 0.95273717, 0.87351033, 0.91171591])

# %%
scores.mean()
# Out:
# 0.9162690195697578
